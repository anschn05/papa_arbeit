# %%
import numpy as np
from math import sqrt
import xyzFile_zusammenrechnen_EW   # greift auf *.py file zu, nicht auf *.ipynb
import xy_KruemmungAnalyse
# def Auflager_gemessen(step,filename_MW,tol):
# def Auflager_generiert(l,b,step,tol):
import HC_AuflagerMinima
# import Analyse_EW
import pyvista as pv
pv.set_jupyter_backend('trame')

import import_ipynb
import xyzFile_GRAVITATION
import Analyse_GRAV
# def gravitationsEinfluss_Auflager(l,b,t,step,auflager_liste,radius):


t = 7.8
l=1550
b = 400
tolMinima = 0.5
Vorzeichen = "Min"
# Vorzeichen = "Max"
# r = l*b/40000
r = 50
step = 40


# Auflager = 'Mitte'
Auflager = 'Aussen'
auflager_liste = [(0,0),(l,0),(l,b),(0,b)]
# auflager_liste = [(l/2,b/2)]



#filename_GRAV = xyzFile_GRAVITATION.gravitationsEinfluss_Auflager(l,b,t,step,Auflager,r)

MaxDifferenz = Analyse_GRAV.Analyse_Grav(t,l,b,Auflager)

#filename_EW = xyzFile_zusammenrechnen_EW.plotten(l,b,t,step,filename_MW,filename_GRAV,Vorzeichen)
print('Laenge:',l,'\nBreite:',b,'\nDicke:',t,'\nAuflager:',Auflager,'\nstep:',step,'\nRadius:',r)
print('--> DIFFERENZ:',MaxDifferenz)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'camera': {'euler_angles': […
# Laenge: 1550
# Breite: 400
# Dicke: 7.8
# Auflager: Aussen
# step: 40
# Radius: 5
# --> DIFFERENZ: 1.02
